# %%
import pandas as pd

# %%
dataset = pd.read_csv("file:///home/rochet/corpora/GDNvsVD-data/GDNvsVD/GDN/LA_TRANSITION_ECOLOGIQUE.csv", delimiter=",")
# Out:
# /home/rochet/Logiciels/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset.head(5)
# Out:
#                                                   id reference  \
# 0  UHJvcG9zYWw6ZmZlN2MwNzktMWUyMC0xMWU5LTk0ZDItZm...       2-4
# 1  UHJvcG9zYWw6M2RmZmUxZjMtMWUyMS0xMWU5LTk0ZDItZm...       2-5
# 2  UHJvcG9zYWw6NDg1YWUxYjItMWUyMS0xMWU5LTk0ZDItZm...       2-6
# 3  UHJvcG9zYWw6NTk2Nzk5MmItMWUyMS0xMWU5LTk0ZDItZm...       2-7
# 4  UHJvcG9zYWw6ODU5NWMyOTYtMWUyMS0xMWU5LTk0ZDItZm...       2-8
#
#                    title            createdAt          publishedAt updatedAt  \
# 0  transition écologique  2019-01-22 09:37:49  2019-01-22 09:37:49       NaN
# 1       La surpopulation  2019-01-22 09:39:33  2019-01-22 09:39:33       NaN
# 2                 climat  2019-01-22 09:39:50  2019-01-22 09:39:50       NaN
# 3      POLLUTION AIR EAU  2019-01-22 09:40:19  2019-01-22 09:40:19       NaN
# 4   Economie vs Ecologie  2019-01-22 09:41:33  2019-01-22 09:41:33       NaN
#
#    trashed trashedStatus                                           authorId  \
# 0    False           NaN  VXNlcjoxMTQwMTc0YS0xZTFmLTExZTktOTRkMi1mYTE2M2...
# 1    False           NaN  VXNlcjpjOWYxZWQ1NS0xYzEwLTExZTktOTRkMi1mYTE2M2...
# 2    False           NaN  VXNlcjozZjlhNzAwOS0xYTc2LTExZTktOTRkMi1mYTE2M2...
# 3    False           NaN  VXNlcjozOWQwNzJjNC0xZDEwLTExZTktOTRkMi1mYTE2M2...
# 4    False           NaN  VXNlcjo3M2YxN2NlZS0xZDRiLTExZTktOTRkMi1mYTE2M2...
#
#             authorType  ...  \
# 0  Citoyen / Citoyenne  ...
# 1  Citoyen / Citoyenne  ...
# 2  Citoyen / Citoyenne  ...
# 3  Citoyen / Citoyenne  ...
# 4  Citoyen / Citoyenne  ...
#
#    QUXVlc3Rpb246MTUw - Qu'est-ce qui pourrait vous inciter à changer vos comportements comme par exemple mieux entretenir et régler votre chauffage, modifier votre manière de conduire ou renoncer à prendre votre véhicule pour de très petites distances ?  \
# 0                                                NaN
# 1                                                NaN
# 2             développer  les transports en commun ,
# 3                                                NaN
# 4  Aménagement de piste cyclable, développement d...
#
#   QUXVlc3Rpb246MTUx - Quelles seraient pour vous les solutions les plus simples et les plus supportables sur un plan financier pour vous inciter à changer vos comportements ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Plus de transports publics dans les petites co...
# 4  Détaxer le mode de chauffage écologique, une a...
#
#   QUXVlc3Rpb246MTUy - Par rapport à votre mode de chauffage actuel, pensez-vous qu'il existe des solutions alternatives plus écologiques ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Non
# 3                                                Non
# 4                                                Oui
#
#   QUXVlc3Rpb246MTUz - Si oui, que faudrait-il faire pour vous convaincre ou vous aider à changer de mode de chauffage ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  une aide significative pour de l'éolien ou du ...
#
#   QUXVlc3Rpb246MTU0 - Avez-vous pour vos déplacements quotidiens la possibilité de recourir à des solutions de mobilité alternatives à la voiture individuelle comme les transports en commun, le covoiturage, l'auto-partage, le transport à la demande, le vélo, etc. ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Oui
# 3                                                Non
# 4                                                Non
#
#   QUXVlc3Rpb246MTU1 - Si oui, que faudrait-il faire pour vous convaincre ou vous aider à utiliser ces solutions alternatives ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Le co-voiturage ne correspond pas toujours aux...
# 4  Une piste cyclable pour éviter de risquer ma v...
#
#   QUXVlc3Rpb246MjA3 - Si non, quelles sont les solutions de mobilité alternatives que vous souhaiteriez pouvoir utiliser ?  \
# 0                                                NaN
# 1                                                NaN
# 2  Les transports en commun|L'auto partage|Le tra...
# 3                           Les transports en commun
# 4    Les transports en commun|Le covoiturage|Le vélo
#
#   QUXVlc3Rpb246MTU3 - Et qui doit selon vous se charger de vous proposer ce type de solutions alternatives ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             L'Etat
# 4              La commune, le département, la région
#
#   QUXVlc3Rpb246MTU4 - Que pourrait faire la France pour faire partager ses choix en matière d'environnement au niveau européen et international ?  \
# 0             Enseignement du tri sélectif à l'école
# 1  Mettre en oeuvre au niveau national ses engage...
# 2                                                NaN
# 3  Elle n'a aucun pouvoir. Impossible de contrain...
# 4                           Demander à Nicolas Hulot
#
#   QUXVlc3Rpb246MTU5 - Y a-t-il d'autres points sur la transition écologique sur lesquels vous souhaiteriez vous exprimer ?
# 0             Multiplier les centrales géothermiques
# 1  Les problèmes auxquels se trouve confronté l’e...
# 2                                                NaN
# 3                                                NaN
# 4    Une vrai politique écologique et non économique
#
# [5 rows x 27 columns]

# %%
questions = dataset.columns[11:]
dataset_filter = dataset[['title', 'authorType', *questions]]
for index, quest in enumerate(questions):
    print(index, quest.split("-", 1)[1])
# Out:
# 0  Quel est aujourd'hui pour vous le problème concret le plus important dans le domaine de l'environnement ?
# 1  Que faudrait-il faire selon vous pour apporter des réponses à ce problème ?
# 2  Diriez-vous que votre vie quotidienne est aujourd'hui touchée par le changement climatique ?
# 3  Si oui, de quelle manière votre vie quotidienne est-elle touchée par le changement climatique ?
# 4  À titre personnel, pensez-vous pouvoir contribuer à protéger l'environnement ?
# 5  Si oui, que faites-vous aujourd'hui pour protéger l'environnement et/ou que pourriez-vous faire ?
# 6  Qu'est-ce qui pourrait vous inciter à changer vos comportements comme par exemple mieux entretenir et régler votre chauffage, modifier votre manière de conduire ou renoncer à prendre votre véhicule pour de très petites distances ?
# 7  Quelles seraient pour vous les solutions les plus simples et les plus supportables sur un plan financier pour vous inciter à changer vos comportements ?
# 8  Par rapport à votre mode de chauffage actuel, pensez-vous qu'il existe des solutions alternatives plus écologiques ?
# 9  Si oui, que faudrait-il faire pour vous convaincre ou vous aider à changer de mode de chauffage ?
# 10  Avez-vous pour vos déplacements quotidiens la possibilité de recourir à des solutions de mobilité alternatives à la voiture individuelle comme les transports en commun, le covoiturage, l'auto-partage, le transport à la demande, le vélo, etc. ?
# 11  Si oui, que faudrait-il faire pour vous convaincre ou vous aider à utiliser ces solutions alternatives ?
# 12  Si non, quelles sont les solutions de mobilité alternatives que vous souhaiteriez pouvoir utiliser ?
# 13  Et qui doit selon vous se charger de vous proposer ce type de solutions alternatives ?
# 14  Que pourrait faire la France pour faire partager ses choix en matière d'environnement au niveau européen et international ?
# 15  Y a-t-il d'autres points sur la transition écologique sur lesquels vous souhaiteriez vous exprimer ?

# %%
index_question = 3

quest, answers = questions[index_question], dataset_filter[quest].values

print("Question selectionnée :")
print(quest.split("-", 1)[1])
# Out:
# Question selectionnée :
#  Si oui, de quelle manière votre vie quotidienne est-elle touchée par le changement climatique ?

# %% [markdown]
# # App

# %%
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nlp = spacy.load('fr')

# %%
def tokenizer(sent):
    return [tok.text for tok in nlp.tokenizer(sent)]

vectorizer = TfidfVectorizer(tokenizer=tokenizer)

answers = [an for an in answers if "nan" != str(an)]
answers_tfidf = vectorizer.fit_transform(answers)

# %%
matrix = vectorizer.transform(answers)

# %%
def search(text):
    # vectorize text
    input_vector = vectorizer.transform([text])
    
    # compute cosinus similarity
    sims_result = cosine_similarity(input_vector, matrix)
    
    # zip in tuples (sentence, similarity)
    result = [*zip(answers, sims_result.squeeze())]
    
    # return most pertinent sentence
    pertinent = sorted(result, key=lambda x: x[1], reverse=True)
    
    
    result_list =  []
    for resp in pertinent:
        if len(resp[0]) < 30:
            result_list.append(resp)
        if len(result_list) == 5:
            break
    
    for an in result_list:
        print(an)
        print("=======")
        
        
    #pertinent = max(result, key=lambda x: x[1])[0]
    #return pertinent

# %%
input_text = input("Question : ")
while input_text != "_stop":
    #print("Réponse :", search(input_text))
    search(input_text)
    input_text = input("Question : ")
# Out:
# Question : tu aimes ta vei ?
# ("Limiter son empreinte environnementale en deçà de la limite acceptable par notre écosystème demande à chaque individu (de pays industrialisé) un réel effort - perte de confort, effort physique, surcoût financier, perte de temps, perte de signes valorisants - tandis que le gain est intangible et collectif. Cela ne peut pas fonctionner. La contrepartie doit être palpable.  L'empreinte écologique individuelle soutenable est connue. Il peut être envisagé de faire payer les individus qui choisissent de polluer au delà et de payer les individus qui fournissent l'effort en deçà de la limite.  Les pollueurs paieront pour la recherche des solutions technologiques nécessaires. Ils financeront aussi ceux qui polluent moins. À l'opposé, ceux qui feront des efforts pour réduire leur impact en deçà de la limite individuelle seront payés proportionnellement à leur effort.  Tu veux ton SUV de 2,5 tonnes pour déplacer ta petite personne. Tu raques ! Tu affrontes les éléments sur ton vieux vélo, entretenu et réparé. Tu empoches !  Tu veux un jet pour ton week-end à l'autre bout du monde. Tu raques ! Tu privilégies le train, la randonnée. Tu empoches !  Tu veux des fruits exotiques transportés par avion. Tu raques ! Tu choisis des fruits de saison de ta région. Tu empoches !  En attendant que la science et la technologie trouvent des solutions.", 0.37775621135735127)
# ("Quand est-ce qu'on va prendre le sujet réellement au sérieux et arrêté de ce cacher derrière de la démagogie à deux balles. Les solutions existent, il faut juste les appliquer ! Que dirons nous aux générations futures : désolé mon petit mais il y avait moyen de se faire beaucoup d'argent, alors ton aire tu la respire avec ta paille et tu me fais pas chier.", 0.27781981348835927)
# ("Tout le monde est d'accord pour apprécier le vert d'une forêt naturelle ou le calme d'un désert.  Ce que les yeux ont vu de plus beau la nature l'a offert.  Qu'elle nous pardonne nos offenses, si cher est la terre.  Aimes la comme tu aimes les bijoux, l'argent et la fête au lieu de la mettre à genoux.  Elle est tout, nous sommes fous, elle a tous les atouts.  Témoin de notre histoire, elle a tout fait pour nous.  Je parle de celle qui nourrit tout les Hommes, mérite-t-elle les baffes qu'on lui donne ?  Est-ce que l'on marche sur la tête ?   Ne craignez-vous pas la tempête ?   Tu me donnes froid, tu me donnes chaud.  Avec toi rien n'est facile.  D'un coup de vent tout peut tomber à l'eau.  Tu me donnes froid, tu me donnes chaud.  En vrai c'est toi qui décide.  D'un coup, d'un seul, tout peut foutre le camp.   Tu me donnes froid, tu me donnes chaud.  Avec toi rien n'est facile.  D'un coup de vent tout peut tomber à l'eau.  Tu me donnes froid, tu me donnes chaud.  En vrai c'est toi qui décide.  D'un coup, d'un seul, tout peut foutre le camp.   La planète est belle mais par elle décède.  Elle était celle qui offrait l'essentiel.  A force de puiser le sang dans ses veines, on la prend, on la prive de son oxygène.   l'homme est un loup pour l'homme  œuvrant pour l’écosystème qu'il dégomme  je le vois qu'il s'enfonce dans l'erreur  en sachant qu'il déconne  mettre la terre a terre pour rester a la mode   On oublierait qu'elle est plus grande que nous.  Un jour viendra nous reprendrons les coups.  Nous sommes tarés, pourris, mon dieu mais c'est effarant.  On nage à contre courant.   Tu me donnes froid, tu me donnes chaud.  Avec toi rien n'est facile.  D'un coup de vent tout peut tomber à l'eau.  Tu me donnes froid, tu me donnes chaud.  En vrai c'est toi qui décide.  D'un coup, d'un seul, tout peut foutre le camp.", 0.2642113690306882)
# ('As-tu regardé le ciel cette nuit ?', 0.245119780276296)
# ('Modifier le système de taxe sur l\'eau + l\'électricité + le gaz Actuellement la facture d\'eau/électricité/gaz fonctionne avec des frais fixes (abonnement + distribution) et des frais variables (en fonction de notre consommation)  Pour quelqu’un qui fait attention au quotidien, les frais fixes peuvent représenter jusqu\'à 75% de la facture, moralité pour ces gens la, en consommant 2 fois plus ils peuvent payer à peine 15% plus cher. C\'est totalement anormal ! Dans ce cas là, pourquoi se priver si pour quelques euros en plus on peut avoir le double de consommation ? Ce mode de calcul n\'est pas du tout en faveur d\'une baisse des consommations.  Pour moi il serait positif de supprimer les frais fixes, d’octroyer à chaque citoyen un "forfait" de première nécessité avec X quantité d\'eau et d\'électricité gratuite ou très peu cher. Puis à partir de ce seuil, faire payer le surplus avec un taux plus élevé qu\'actuellement.  En moyenne le prix de revient aux entreprises + état seront identiques mais les gens qui consomment le plus payeront pour les gens qui ont une utilisation raisonnée des ressources.  Ce barème serait en plus incitatif pour réduire les consommations  ==> Tu remplis ta piscine = tu payes pour ceux qui n\'en ont pas ==> Tu chauffes ta maison constamment = tu payes pour ceux qui préfèrent mettre un pull etc...', 0.24272856148428523)
# ('Indexer la retraite des très hauts fonctionnaires sur leurs résultats à très long terme. Tu es député en 2020, tu bosses bien pour la planète, tu as droit à une belle retraite en 2050. T’as rien foutu, la France consomme encore plus d’ énergie, émet toujours plus de carbone : pas de retraite !', 0.2281938445827597)
# ("Agis de telle sorte que tu traites l'humanité, aussi bien dans ta personne que dans la personne de tout autre, toujours en même temps comme une fin, et jamais simplement comme un moyen (Kant). Le modèle libéral de la réussite individuelle conduit à la fin de notre espèce et de bien d'autres.", 0.22610975441041323)
# ("je pense qu'il faut vraiment développer les transports pour les camions de marchandise par le ferroviaire tu veux livrer en Espagne en passant par la France tu mets ton camion sur un train cela tomberait bien avec l'ouverture a la concurrence", 0.22456493686922613)
# ("Arrêté la politique: si tu fait pas tu paie!  Usé de pédagogie, expliquer, montré qu'il est possible de faire aussi bien avec autre chose et si cette autre chose me fait économiser de l'argent... même un égoïste borné peut changer d'avis.", 0.21008645502765136)
# ("J'en reviens à l'argent, si tu as les moyens tu peux avoir une voiture qui consomment 25 litres au cent, on ne te dira rien. Pourquoi ne pas interdire la fabrication à partir d'un date précise de tous véhicules consommant plus de 5 litres de moyennes ? la au moins pas de jaloux.", 0.20283113141823145)
# ('?', 0.18839649444833276)
# ('?', 0.18839649444833276)
# =======
